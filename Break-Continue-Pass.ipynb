# %%
name='bhuvi'
age=24
salary=100000.50

# %%
print('my name is %s my age is %i my salary is %f' %(name,age,salary))
# Out:
# my name is bhuvi my age is 24 my salary is 100000.000000

# %%
print('my name is {0} my age is {1} my salary is {2}'.format(name,age,salary))
# Out:
# my name is bhuvi my age is 24 my salary is 100000

# %%
a=['kavi','priya','karthiga','bhuvi']

# %%
a
# Out:
# ['kavi', 'priya', 'karthiga', 'bhuvi']

# %%
for i in a:
    print(i)
    if i=='karthiga':
        print('closed')
        break
# Out:
# kavi
# priya
# karthiga
# closed

# %%
for i in a:
    print(i)
    if i=='karthiga':
        print('closed')
        continue
# Out:
# kavi
# priya
# karthiga
# closed
# bhuvi

# %%
a
# Out:
# ['kavi', 'priya', 'karthiga', 'bhuvi']

# %%
for i in range(10):
    print(i**2)
    continue
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
for i in range(10):
    continue
print(i*i)
# Out:
# 81

# %%
for i in range(10):
    pass

# %%
for i in range(10):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a='bhuvi'

# %%
a.upper()
# Out:
# 'BHUVI'

# %%
a.lower()
# Out:
# 'bhuvi'

# %%
a='BhUvI'

# %%
a.swapcase()
# Out:
# 'bHuVi'

# %%
a='bhuvi is a good boy'

# %%
a.title()
# Out:
# 'Bhuvi Is A Good Boy'

# %%
a.capitalize()
# Out:
# 'Bhuvi is a good boy'

# %%
a.startswith('b')
# Out:
# True

# %%
a.endswith('y')
# Out:
# True

# %%
a
# Out:
# 'bhuvi is a good boy'

# %%
a.isalnum()
# Out:
# False

# %%
--> to use .isalnum there should not be any space and it can have alphabets and numericals
--> to use .isalpha "       " and only it can have alphabets
--> to use .isdidgit "      " and only it can have numericals

# %%
a='dndccaoc'

# %%
a.isalnum()
# Out:
# True

# %%
a.isalpha()
# Out:
# True

# %%
print('bhuvi',end='')
print('kavi',end='')
print('alien')
# Out:
# bhuvikavialien

# %%
for i in range(10):
    print(i,end='')
# Out:
# 0123456789

# %%
for i in range(10):
    print('#',end='')
# Out:
# ##########

# %%
for i in range(10):
    print('@',end='')
    for j in range(5):
        print('#',end='')
# Out:
# @#####@#####@#####@#####@#####@#####@#####@#####@#####@#####

# %%
for i in range(10):
    print('@')
    for j in range(5):
        print('#',end='')
# Out:
# @
# #####@
# #####@
# #####@
# #####@
# #####@
# #####@
# #####@
# #####@
# #####@
# #####

# %%
for i in range(10):
    print('@',end='')
    for j in range(5):
        print('#')
# Out:
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #
# @#
# #
# #
# #
# #

# %%
print('    *    ')
print('*       *')
print('*       *')
print('*   *   *')
print('*       *')
print('*       *')
# Out:
#     *
# *       *
# *       *
# *   *   *
# *       *
# *       *

# %%
for i in range(6):
    if i==0:
        print('   *  ')
    elif i==3:
        print('*  * *')
    else:
        print('*    *')
# Out:
#    *
# *    *
# *    *
# *  * *
# *    *
# *    *
